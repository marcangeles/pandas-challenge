# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_df = pd.read_csv(file_to_load)
purchase_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
players= len(purchase_df["SN"].value_counts())
player_count=pd.DataFrame([player], columns = ["Total Players"])

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
Unique_items = purchase_df["Item ID"].nunique()
Unique_items
Average_price = purchase_df["Price"].mean()
Average_price
Num_of_purchases = purchase_df["Item ID"].count()
Num_of_purchases
Total_revenue = purchase_df["Price"].sum()
Total_revenue

purchase_summary=pd.DataFrame({"Number of Unique Items ":[Unique_items],
                            "Average Price " : [Average_price],
                            "Num of Purchases ": [Num_of_purchases],
                            "Total Revenue " : [Total_revenue]})
purchase_summary
# Out:
#    Number of Unique Items   Average Price   Num of Purchases   Total Revenue
# 0                      183        3.050987                780         2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
Gender = purchase_df[["SN", "Gender"]]

Gender = gender.drop_duplicates()

Count = gender["Gender"].value_counts()

# List of values
Total_counts = [counts[0],counts[1],counts[2]]
percents = [round((counts[0]/player)*100,2),round((counts[1]/player)*100,2),round((counts[2]/player)*100,2)]

# Creating DataFrame & setting index
gender_PSummary = pd.DataFrame({"Percentage of Players": percents,"Total Count": total_counts})
gender_PSummary.index = (["Male", "Female", "Other / Non-Disclosed"])
gender_demo
# Out:
#                        Percentage of Players  Total Count
# Male                                   84.03          484
# Female                                 14.06           81
# Other / Non-Disclosed                   1.91           11

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
Gender = purchase_df.groupby(["Gender"])

#Basic Calculations
Purchase_Count = Gender["SN"].count()

Purchase_Price = Gender["Price"].mean()

Purchase_Value = Gender["Price"].sum()


duplicates = purchase_df.drop_duplicates(subset='SN', keep="first")
grouped_dup = duplicates.groupby(["Gender"])

# Find normalized data
Norm_Purchase = (gender["Price"].sum() / grouped_dup["SN"].count())

# Creating new DataFrame
gender_purchase = pd.DataFrame({ "Purchase Count": Purchase_Count,
                              "Avg Purchase Price": Purchase_Price,
                              "Total Purchase Value": Purchase_Value,
                              "Normalized Totals": Norm_Purchase})
# DF formatting
gender_purchase["Avg Purchase Price"] = gender_purchase["Avg Purchase Price"].map("${:.2f}".format)
gender_purchase["Total Purchase Value"] = gender_purchase["Total Purchase Value"].map("${:.2f}".format)
gender_purchase["Normalized Totals"] = gender_purchase["Normalized Totals"].map("${:.2f}".format)
gender_purchase = gender_purchase[["Purchase Count", "Avg Purchase Price", "Total Purchase Value", "Normalized Totals"]]
gender_purchase
# Out:
#                        Purchase Count Avg Purchase Price Total Purchase Value  \
# Gender
# Female                            113              $3.20              $361.94
# Male                              652              $3.02             $1967.64
# Other / Non-Disclosed              15              $3.35               $50.19
#
#                       Normalized Totals
# Gender
# Female                            $4.47
# Male                              $4.07
# Other / Non-Disclosed             $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Set age bins
Age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]

Age_groups = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#DF for age bin
purchase_df["Age Demographics"]= pd.cut(purchase_data["Age"], age_bins, labels= Age_groups)

demographic_group = purchase_df.groupby("Age Demographics")

demographic_group.head(10)
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 446          446   Chanossast57    7  Female      119
# 477          477     Mindossa76   41    Male      173
# 480          480      Salilis27   40    Male       59
# 557          557     Frichaya88   42    Male        8
# 667          667      Inasuir29   40  Female       66
#
#                                      Item Name  Price Age Demographics  \
# 0    Extraction, Quickblade Of Trembling Hands   3.53            20-24
# 1                            Frenzied Scimitar   1.56              40+
# 2                                 Final Critic   4.88            20-24
# ...

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
age_purchasing_df = purchase_df
age_purchasing_df['demographic_group'] = pd.cut(purchase_df['Age'], age_bins, labels = Age_groups)

Purchasing_analysis_age_df = age_purchasing_df[['Price', 'Age Groups']].groupby(['Age Groups']).count()

Purchasing_analysis_age_df['Average Purchase Price'] = age_purchasing_df[['Price', 'Age Groups']].groupby(['Age Groups']).mean()

Purchasing_analysis_age_df['Total Purchase Price'] = age_purchasing_df[['Price', 'Age Groups']].groupby(['Age Groups']).sum()

Purchasing_analysis_age_df['Normalized Totals'] = (age_purchasing_analysis_df['Total Purchase Price'] / purchase_data["Age Demographics"])

Purchasing_analysis_age_df['Average Purchase Price'] = age_purchasing_analysis_df['Average Purchase Price'].map('${:,.2f}'.format)

Purchasing_analysis_age_df['Total Purchase Price'] = age_purchasing_analysis_df['Total Purchase Price'].map('${:,.2f}'.format)

Purchasing_analysis_age_df['Normalized Totals'] = age_purchasing_analysis_df['Normalized Totals'].map('${:,.2f}'.format)

Purchasing_analysis_age_df.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/envs/PythonClass/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age Demographics'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-3e40aab38987> in <module>
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
age_purchasing_df = purchase_data
age_purchasing_df['Age Groups'] = pd.cut(purchase_data['Age'], age_bins, labels = group_names)

age_purchasing_analysis_df = age_purchasing_df[['Price', 'Age Groups']].groupby(['Age Groups']).count()
age_purchasing_analysis_df['Average Purchase Price'] = age_purchasing_df[['Price', 'Age Groups']].groupby(['Age Groups']).mean()
age_purchasing_analysis_df['Total Purchase Price'] = age_purchasing_df[['Price', 'Age Groups']].groupby(['Age Groups']).sum()
age_purchasing_analysis_df['Normalized Totals'] = (age_purchasing_analysis_df['Total Purchase Price'] / purchase_data["Age Demographics"])

age_purchasing_analysis_df['Average Purchase Price'] = age_purchasing_analysis_df['Average Purchase Price'].map('${:,.2f}'.format)
age_purchasing_analysis_df['Total Purchase Price'] = age_purchasing_analysis_df['Total Purchase Price'].map('${:,.2f}'.format)
age_purchasing_analysis_df['Normalized Totals'] = age_purchasing_analysis_df['Normalized Totals'].map('${:,.2f}'.format)

age_purchasing_analysis_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-d3d930defe32> in <module>
#       1 age_purchasing_df = purchase_data
# ----> 2 age_purchasing_df['Age Groups'] = pd.cut(purchase_data['Age'], age_bins, labels = group_names)
#       3
#       4 age_purchasing_analysis_df = age_purchasing_df[['Price', 'Age Groups']].groupby(['Age Groups']).count()
#       5 age_purchasing_analysis_df['Average Purchase Price'] = age_purchasing_df[['Price', 'Age Groups']].groupby(['Age Groups']).mean()
#
# NameError: name 'group_names' is not defined

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#define most items 
Most_popu_items = purchase_data.groupby(['Item ID', 'Item Name','Price'])['Price'].agg(['count','sum'])

Most_popu_items.columns = ['Purchase Count', 'Total Purchase Value']
 
Most_popu_items.reset_index(inplace=True)

Most_popu_items.set_index(['Item ID','Item Name'] ,inplace=True)

Popu_items = Popu_items[['Purchase Count', 'Price', 'Total Purchase Value']]

most_popular_items = most_items.sort_values(by='Purchase Count', ascending=False)


most_popular_items['Price'] = most_popular_items['Price'].map('${:,.2f}'.format)
most_popular_items['Total Purchase Value'] = most_popular_items['Total Purchase Value'].map('${:,.2f}'.format)

most_popular_items.head()
# Out:
#                                                       Purchase Count  Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12  $4.23
# 145     Fiery Glass Crusader                                       9  $4.58
# 108     Extraction, Quickblade Of Trembling Hands                  9  $3.53
# 82      Nirvana                                                    9  $4.90
# 19      Pursuit, Cudgel of Necromancy                              8  $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77
# 82      Nirvana                                                    $44.10
# 19      Pursuit, Cudgel of Necromancy                               $8.16

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
#in descending order 
most_profitable_items = most_items.sort_values(by='Total Purchase Value', ascending=False)

most_profitable_items['Price'] = most_profitable_items['Price'].map('${:,.2f}'.format)
most_profitable_items['Total Purchase Value'] = most_profitable_items['Total Purchase Value'].map('${:,.2f}'.format)
most_profitable_items.head()
# Out:
#                                                       Purchase Count  Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12  $4.23
# 82      Nirvana                                                    9  $4.90
# 145     Fiery Glass Crusader                                       9  $4.58
# 92      Final Critic                                               8  $4.88
# 103     Singed Scalpel                                             8  $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 92      Final Critic                                               $39.04
# 103     Singed Scalpel                                             $34.80
